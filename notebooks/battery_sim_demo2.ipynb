# %%
# %load_ext autoreload
# %autoreload 2

# %%
import random
import battery_sim

bat = battery_sim.battery()

# %%
# Get bounds for operation - charge and discharge:
print(f"Available Energy {bat.avl_energy} kWh")
print(f"Max input: {bat.get_charge_potential()} kWh")
print(f"Max output: {bat.get_discharge_potential()} kWh")
# Out:
# Available Energy 0 kWh
# Max input: 0.41666666666666663 kWh
# Max output: 0.0 kWh

# %%
# Charge the battery with too much power
bat.charge_(11)
# Out:
# ---------------------------------------------------------------------------
# BatteryOverflowError                      Traceback (most recent call last)
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_13272/1271524763.py in <module>
#       1 # Charge the battery with too much power
# ----> 2 bat.charge_(11)
#
# ~\OneDrive\Berkeley\Courses\W210\home-energy-optimizer\battery_sim.py in charge_(self, input_energy)
#     122
#     123         if input_energy > available_capacity:
# --> 124             raise BatteryOverflowError
#     125         else:
#     126             # Calculate the actual amount decremented
#
# BatteryOverflowError:

# %%
# Charge the battery with max charge rate
first_charge = bat.get_charge_potential() 

# charge battery
bat.charge_(first_charge)
# print updated available energy
bat.avl_energy
# Out:
# 0.3952847075210474

# %%
# Check that new availabe energy = max charge rate x charge losses
bat.avl_energy == bat.get_charge_potential() * bat.charge_loss
# Out:
# True

# %%
# Get discharge potential - how much energy i could recover, taking into account discharge losses
first_discharge = bat.get_discharge_potential()
first_discharge
# Out:
# 0.37499999999999994

# %%
# Check round trip efficiency calculation:
first_discharge / first_charge
# Out:
# 0.8999999999999999

# %%
# Discharge battery
bat.discharge_(first_discharge)
# Out:
# (0.3952847075210474, 0.0)

# %%
# Check empty.
bat.avl_energy
# Out:
# 0.0

# %%
# degredation demo
t = battery_sim.battery()

# Random array of outputs
energy= [-5,3,2,5,-10,3,5,8,10,2,-4,6,-3,2,1,3,5,2,9]

for e in energy:
    # decrememnt only (doesn't call the charging/discharing functions)
    t.update_capacity_degredation(e)
    print(f"Max Capacity: {t.capacity:.5f}, Total Energy in/out: {t.total_energy_flow}, Energy:{e}, trips: {t.trip_count}, previous: {t.previous_trip_count}")
# Out:
# Max Capacity: 14.00000, Total Energy in/out: 5, Energy:-5, trips: 0, previous: 0
# Max Capacity: 14.00000, Total Energy in/out: 8, Energy:3, trips: 0, previous: 0
# Max Capacity: 14.00000, Total Energy in/out: 10, Energy:2, trips: 0, previous: 0
# Max Capacity: 14.00000, Total Energy in/out: 15, Energy:5, trips: 0, previous: 0
# Max Capacity: 14.00000, Total Energy in/out: 25, Energy:-10, trips: 0, previous: 0
# Max Capacity: 13.99975, Total Energy in/out: 28, Energy:3, trips: 1, previous: 1
# Max Capacity: 13.99975, Total Energy in/out: 33, Energy:5, trips: 1.0, previous: 1.0
# Max Capacity: 13.99975, Total Energy in/out: 41, Energy:8, trips: 1.0, previous: 1.0
# Max Capacity: 13.99975, Total Energy in/out: 51, Energy:10, trips: 1.0, previous: 1.0
# Max Capacity: 13.99975, Total Energy in/out: 53, Energy:2, trips: 1.0, previous: 1.0
# Max Capacity: 13.99950, Total Energy in/out: 57, Energy:-4, trips: 2.0, previous: 2.0
# Max Capacity: 13.99950, Total Energy in/out: 63, Energy:6, trips: 2.0, previous: 2.0
# Max Capacity: 13.99950, Total Energy in/out: 66, Energy:-3, trips: 2.0, previous: 2.0
# Max Capacity: 13.99950, Total Energy in/out: 68, Energy:2, trips: 2.0, previous: 2.0
# Max Capacity: 13.99950, Total Energy in/out: 69, Energy:1, trips: 2.0, previous: 2.0
# Max Capacity: 13.99950, Total Energy in/out: 72, Energy:3, trips: 2.0, previous: 2.0
# Max Capacity: 13.99950, Total Energy in/out: 77, Energy:5, trips: 2.0, previous: 2.0
# Max Capacity: 13.99950, Total Energy in/out: 79, Energy:2, trips: 2.0, previous: 2.0
# Max Capacity: 13.99925, Total Energy in/out: 88, Energy:9, trips: 3.0, previous: 3.0

# %% [markdown]
# ### Simulation - Status Quo
#
# Interval = 5 minutes
#
# #### Tariff Spects:
#
# - Import Tariff: ToU
# - Export Tariff: SolarFit
#
# #### Battery Specs
#
# - Grid Export Allowed: False
# - Grid Charging Allowed: False
# - Power Priority: Load
# - Charge Priority: Solar
#
# #### Solar Specs:
#
# - Solar Pesent: True
#
# #### Sign Conventions:
#
# Note: Solar cannot import, and loads cannot export energy.
#
# | Component | Import | Export |
# | --- | --- | --- |
# | **Solar** | Not Applicable | Negative (-) |
# | **Battery** | (Charge) Positive (+) | (Discharge) Negative (-) |
# | **Loads** | (Consumption) Positive (+) | Not Applicable |
# | **Grid** | (Consumption) Positive (+) | Negative (-) |
#
#
# Logic
#
# |          State                               |        Action Space             | Comment |
# | --- | --- | --- |
# | solar on, with load, solar greater than load | battery: [0, abs(solar + load)] |charging from solar excess   |
# | solar on, with load, solar less than load    | battery: [0, abs(solar + load)] |powering deficit load   |
# | solar on, no load                            | battery: [0, abs(solar)]        |charging from solar excess     |
# | solar off, with load                         | battery: [-load, 0]             |battery can power load  |
# | solar off, no load                           | battery: [0]                    |battery can do nothing  |

# %%
print("""
Battery cannot export or charge from the grid (solar only). We expect to see:
- charge/discharge values not greater than the limit value. 
- charge only possible with net solar, and bounded appropriately by max or available solar. 
- discharge only possible with available capacity, and bounded by max or available load.
""")

for k in [0, 0.5, 1]:
    
    bat = battery_sim.battery(dischargeable=False, importable=False)
    bat.capacity = 1
    bat.avl_energy =k

    # Get bounds for operation - charge and discharge:
    print(f"\nAvailable Energy {bat.avl_energy} kWh\n"
          f"Max input: {bat.get_charge_potential()} kWh\n"
          f"Max output: {bat.get_discharge_potential()} kWh\n")

    for i in range(20):
        Load = random.random()
        Solar = random.random() * -1

        max_c = bat.get_charge_potential()
        max_d = bat.get_discharge_potential()
        a_d, a_c = bat.get_limits(Solar, Load)
        print(f"Net: {Solar+Load:3.4f}, SoC: {bat.avl_energy / bat.capacity * 100 :2.4f}%"
              f", Discharge (bound/limit): {a_d:2.4f}/{max_d:2.4f}, "
              f"Charge (bound/limit): {a_c:2.4f}/{max_c:2.4f}")
# Out:
# Battery cannot export or charge from the grid (solar only). We expect to see:
# - charge/discharge values not greater than the limit value.
# - charge only possible with net solar, and bounded appropriately by max or available solar.
# - discharge only possible with available capacity, and bounded by max or available load.
#
#
# Available Energy 0 kWh
# Max input: 0.41666666666666663 kWh
# Max output: 0.0 kWh
#
# Net: 0.4358, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.3645, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.3645/0.4167
# Net: 0.1749, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.6593, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.2412, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.0336, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.1444, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.3249, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.3249/0.4167
# Net: -0.2104, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.2104/0.4167
# Net: -0.4548, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.4592, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.2070, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.6940, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.3017, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.2257, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.2257/0.4167
# Net: -0.9617, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.2491, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.2491/0.4167
# Net: 0.0615, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.1930, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.7506, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
#
# Available Energy 0.5 kWh
# Max input: 0.41666666666666663 kWh
# Max output: 0.41666666666666663 kWh
#
# Net: -0.3051, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.3051/0.4167
# Net: 0.3760, SoC: 50.0000%, Discharge (bound/limit): -0.3760/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: 0.6131, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: -0.6520, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1680, SoC: 50.0000%, Discharge (bound/limit): -0.1680/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: -0.1874, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.1874/0.4167
# Net: 0.1929, SoC: 50.0000%, Discharge (bound/limit): -0.1929/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: -0.3308, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.3308/0.4167
# Net: 0.2512, SoC: 50.0000%, Discharge (bound/limit): -0.2512/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: 0.4569, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: 0.3039, SoC: 50.0000%, Discharge (bound/limit): -0.3039/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: -0.5050, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1535, SoC: 50.0000%, Discharge (bound/limit): -0.1535/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: -0.3049, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.3049/0.4167
# Net: -0.0419, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0419/0.4167
# Net: -0.3545, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.3545/0.4167
# Net: -0.0559, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0559/0.4167
# Net: 0.7347, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: 0.4093, SoC: 50.0000%, Discharge (bound/limit): -0.4093/0.4167, Charge (bound/limit): 0.0000/0.4167
# Net: -0.5155, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
#
# Available Energy 1 kWh
# Max input: 0.0 kWh
# Max output: 0.41666666666666663 kWh
#
# Net: 0.0356, SoC: 100.0000%, Discharge (bound/limit): -0.0356/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.2719, SoC: 100.0000%, Discharge (bound/limit): -0.2719/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.4769, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.6204, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0385, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0926, SoC: 100.0000%, Discharge (bound/limit): -0.0926/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.5768, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.5753, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.5777, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0874, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0617, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0629, SoC: 100.0000%, Discharge (bound/limit): -0.0629/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.1426, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.3936, SoC: 100.0000%, Discharge (bound/limit): -0.3936/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.5139, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.5210, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.5473, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.5804, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0584, SoC: 100.0000%, Discharge (bound/limit): -0.0584/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.1166, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000

# %%
print("""
Battery can export, but cannot charge from the grid (solar only). We expect to see:
- charge/discharge values not greater than the limit value. 
- charge only possible with net solar, and bounded appropriately by max or available solar. 
- discharge only possible with available capacity, and bounded by max - can be greater than load!.
""")

for k in [0, 0.4, 1]:
    
    bat = battery_sim.battery(dischargeable=True, importable=False)
    bat.capacity = 1
    bat.avl_energy =k

    # Get bounds for operation - charge and discharge:
    print(f"\nAvailable Energy {bat.avl_energy} kWh\n"
          f"Max input: {bat.get_charge_potential()} kWh\n"
          f"Max output: {bat.get_discharge_potential()} kWh\n")

    for i in range(20):
        Load = random.random()
        Solar = random.random() * -1

        max_c = bat.get_charge_potential()
        max_d = bat.get_discharge_potential()
        a_d, a_c = bat.get_limits(Solar, Load)
        print(f"Net: {Solar+Load:3.4f}, SoC: {bat.avl_energy / bat.capacity * 100 :2.4f}%"
              f", Discharge (bound/limit): {a_d:2.4f}/{max_d:2.4f}, "
              f"Charge (bound/limit): {a_c:2.4f}/{max_c:2.4f}")
# Out:
# Battery cannot export or charge from the grid (solar only). We expect to see:
# - charge/discharge values not greater than the limit value.
# - charge only possible with net solar, and bounded appropriately by max or available solar.
# - discharge only possible with available capacity, and bounded by max - can be greater than load!.
#
#
# Available Energy 0 kWh
# Max input: 0.41666666666666663 kWh
# Max output: 0.0 kWh
#
# Net: -0.3439, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.3439/0.4167
# Net: 0.0703, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.8628, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.5319, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.6830, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1193, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.2657, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.3438, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.3438/0.4167
# Net: -0.1867, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.1867/0.4167
# Net: 0.5400, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.5178, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.0513, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0513/0.4167
# Net: -0.2181, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.2181/0.4167
# Net: 0.1668, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: 0.6161, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.3772, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.3772/0.4167
# Net: -0.4390, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.3965, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.3965/0.4167
# Net: 0.6027, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0000/0.4167
# Net: -0.0961, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.0961/0.4167
#
# Available Energy 0.4 kWh
# Max input: 0.41666666666666663 kWh
# Max output: 0.37947331922020555 kWh
#
# Net: 0.4638, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0000/0.4167
# Net: -0.0844, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0844/0.4167
# Net: -0.0909, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0909/0.4167
# Net: 0.4760, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0000/0.4167
# Net: 0.8262, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0000/0.4167
# Net: -0.8208, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.4167/0.4167
# Net: 0.2656, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0000/0.4167
# Net: -0.2950, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.2950/0.4167
# Net: -0.0304, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0304/0.4167
# Net: 0.0686, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0000/0.4167
# Net: -0.5193, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.4167/0.4167
# Net: -0.6308, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.4167/0.4167
# Net: 0.0090, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0000/0.4167
# Net: -0.3034, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.3034/0.4167
# Net: -0.2609, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.2609/0.4167
# Net: -0.6024, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.4167/0.4167
# Net: -0.6126, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.4167/0.4167
# Net: 0.2279, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0000/0.4167
# Net: -0.4347, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.4167/0.4167
# Net: 0.3155, SoC: 40.0000%, Discharge (bound/limit): -0.3795/0.3795, Charge (bound/limit): 0.0000/0.4167
#
# Available Energy 1 kWh
# Max input: 0.0 kWh
# Max output: 0.41666666666666663 kWh
#
# Net: 0.8288, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.4345, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.3760, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.2527, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0442, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0413, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0398, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.2879, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.8559, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.2790, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.4837, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0359, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0975, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.7907, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.7214, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.2709, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.8131, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.1780, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.7414, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.2767, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000

# %%
print("""
Battery cannot export but can charge from the grid (solar only). We expect to see:
- charge/discharge values not greater than the limit value. 
- charge only possible with net solar or grid, and bounded appropriately by max. 
- discharge only possible with available capacity, and bounded by max or available load.
""")

for k in [0, 0.5, 1]:
    
    bat = battery_sim.battery(dischargeable=False, importable=True)
    bat.capacity = 1
    bat.avl_energy =k

    # Get bounds for operation - charge and discharge:
    print(f"\nAvailable Energy {bat.avl_energy} kWh\n"
          f"Max input: {bat.get_charge_potential()} kWh\n"
          f"Max output: {bat.get_discharge_potential()} kWh\n")

    for i in range(20):
        Load = random.random()
        Solar = random.random() * -1

        max_c = bat.get_charge_potential()
        max_d = bat.get_discharge_potential()
        a_d, a_c = bat.get_limits(Solar, Load)
        print(f"Net: {Solar+Load:3.4f}, SoC: {bat.avl_energy / bat.capacity * 100 :2.4f}%"
              f", Discharge (bound/limit): {a_d:2.4f}/{max_d:2.4f}, "
              f"Charge (bound/limit): {a_c:2.4f}/{max_c:2.4f}")
# Out:
# Battery cannot export but can charge from the grid (solar only). We expect to see:
# - charge/discharge values not greater than the limit value.
# - charge only possible with net solar or grid, and bounded appropriately by max.
# - discharge only possible with available capacity, and bounded by max or available load.
#
#
# Available Energy 0 kWh
# Max input: 0.41666666666666663 kWh
# Max output: 0.0 kWh
#
# Net: 0.1555, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.0659, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1787, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1353, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.0105, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.4761, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.3627, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.0316, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.1102, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.2531, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.3295, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.4877, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.8272, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.0374, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1102, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.2424, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1965, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.1849, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.4526, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.6517, SoC: 0.0000%, Discharge (bound/limit): 0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
#
# Available Energy 0.5 kWh
# Max input: 0.41666666666666663 kWh
# Max output: 0.41666666666666663 kWh
#
# Net: 0.5375, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.2402, SoC: 50.0000%, Discharge (bound/limit): -0.2402/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.1435, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.2083, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.8871, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.2887, SoC: 50.0000%, Discharge (bound/limit): -0.2887/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.6887, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.0683, SoC: 50.0000%, Discharge (bound/limit): -0.0683/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.0277, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.4697, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.2996, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.0415, SoC: 50.0000%, Discharge (bound/limit): -0.0415/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.2150, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.5230, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.0291, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.4169, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.4934, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.6190, SoC: 50.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.0860, SoC: 50.0000%, Discharge (bound/limit): -0.0860/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1545, SoC: 50.0000%, Discharge (bound/limit): -0.1545/0.4167, Charge (bound/limit): 0.4167/0.4167
#
# Available Energy 1 kWh
# Max input: 0.0 kWh
# Max output: 0.41666666666666663 kWh
#
# Net: 0.5686, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.3923, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0345, SoC: 100.0000%, Discharge (bound/limit): -0.0345/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0411, SoC: 100.0000%, Discharge (bound/limit): -0.0411/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0275, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.6924, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.1439, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.3499, SoC: 100.0000%, Discharge (bound/limit): -0.3499/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.4914, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.5386, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.1333, SoC: 100.0000%, Discharge (bound/limit): -0.1333/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.1544, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.3073, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.1532, SoC: 100.0000%, Discharge (bound/limit): -0.1532/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.5754, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.3339, SoC: 100.0000%, Discharge (bound/limit): -0.3339/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.2266, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.7987, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.3112, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.4855, SoC: 100.0000%, Discharge (bound/limit): 0.0000/0.4167, Charge (bound/limit): 0.0000/0.0000

# %%
print("""
Battery can export and charge from the grid (solar only). We expect to see:
- charge/discharge values not greater than the limit value. 
- charge only possible with net solar and grid, and bounded appropriately by max. 
- discharge only possible with available capacity, and bounded by max - can be greater than load!.
""")

for k in [0, 0.5, 1]:
    
    bat = battery_sim.battery(dischargeable=True, importable=True)
    bat.capacity = 1
    bat.avl_energy =k

    # Get bounds for operation - charge and discharge:
    print(f"\nAvailable Energy {bat.avl_energy} kWh\n"
          f"Max input: {bat.get_charge_potential()} kWh\n"
          f"Max output: {bat.get_discharge_potential()} kWh\n")

    for i in range(20):
        Load = random.random()
        Solar = random.random() * -1

        max_c = bat.get_charge_potential()
        max_d = bat.get_discharge_potential()
        a_d, a_c = bat.get_limits(Solar, Load)
        print(f"Net: {Solar+Load:3.4f}, SoC: {bat.avl_energy / bat.capacity * 100 :2.4f}%"
              f", Discharge (bound/limit): {a_d:2.4f}/{max_d:2.4f}, "
              f"Charge (bound/limit): {a_c:2.4f}/{max_c:2.4f}")
# Out:
# Battery can export and charge from the grid (solar only). We expect to see:
# - charge/discharge values not greater than the limit value.
# - charge only possible with net solar and grid, and bounded appropriately by max.
# - discharge only possible with available capacity, and bounded by max - can be greater than load!.
#
#
# Available Energy 0 kWh
# Max input: 0.41666666666666663 kWh
# Max output: 0.0 kWh
#
# Net: 0.8340, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.4880, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.7588, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.8500, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.7167, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.4113, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.3412, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.2097, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.4747, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.4083, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.4542, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.3517, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.2579, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1277, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.9032, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.7244, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1808, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.3767, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: 0.3523, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Net: -0.7276, SoC: 0.0000%, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
#
# Available Energy 0.5 kWh
# Max input: 0.41666666666666663 kWh
# Max output: 0.41666666666666663 kWh
#
# Net: 0.3031, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.2044, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.3855, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.0506, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.3362, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.2292, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.7093, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.6126, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.9043, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.0229, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.8236, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.1543, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.9045, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.1778, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.6479, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.0601, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.7529, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: -0.4334, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.0750, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Net: 0.2407, SoC: 50.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
#
# Available Energy 1 kWh
# Max input: 0.0 kWh
# Max output: 0.41666666666666663 kWh
#
# Net: 0.2098, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.5400, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.2953, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0762, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.1542, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.4277, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0913, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.4893, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.6061, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.5673, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0962, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0119, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.1227, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.4785, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0898, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.4412, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.1054, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: -0.0939, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.2822, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Net: 0.0600, SoC: 100.0000%, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000

# %%
print("""
Battery can export and charge from the grid (solar only). We expect to see:
- charge/discharge values not greater than the limit value. 
- charge only possible with net solar and grid, and bounded appropriately by max. 
- discharge only possible with available capacity, and bounded by max - can be greater than load!.
""")

for k in [0, 0.5, 1]:
    
    bat = battery_sim.battery(dischargeable=True, importable=True)
    bat.capacity = 1
    bat.avl_energy = k

    # Get bounds for operation - charge and discharge:
    print(f"\nAvailable Energy {bat.avl_energy} kWh\n"
          f"Max input: {bat.get_charge_potential():.4f} kWh\n"
          f"Max output: {bat.get_discharge_potential():.4f} kWh\n")

    for i in range(10):
        Load = random.random()
        Solar = random.random() * -1

        max_c = bat.get_charge_potential()
        max_d = bat.get_discharge_potential()
        a_d, a_c = bat.get_limits(Solar, Load)
        print(f"Net: {Solar+Load:3.4f}, Avl Energy: {bat.avl_energy:2.4f} kWh"
              f", Discharge (bound/limit): {a_d:2.4f}/{max_d:2.4f}, "
              f"Charge (bound/limit): {a_c:2.4f}/{max_c:2.4f}")
        
        energy = random.sample(np.linspace(a_d, a_c, 100).tolist(), 1)[0]
        if energy > 0:
            print(f"Charging! {energy:2.4f} kWh")
            bat.charge_(energy)
        else:
            print(f"Discharging! {energy:2.4f} kWh")
            bat.discharge_(-energy)
# Out:
# Battery can export and charge from the grid (solar only). We expect to see:
# - charge/discharge values not greater than the limit value.
# - charge only possible with net solar and grid, and bounded appropriately by max.
# - discharge only possible with available capacity, and bounded by max - can be greater than load!.
#
#
# Available Energy 0 kWh
# Max input: 0.4167 kWh
# Max output: 0.0000 kWh
#
# Net: 0.4037, Avl Energy: 0.0000 kWh, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.0547 kWh
# Net: -0.2937, Avl Energy: 0.0519 kWh, Discharge (bound/limit): -0.0492/0.0492, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.2896 kWh
# Net: 0.9793, Avl Energy: 0.3266 kWh, Discharge (bound/limit): -0.3099/0.3099, Charge (bound/limit): 0.4167/0.4167
# Discharging! -0.1484 kWh
# Net: 0.5653, Avl Energy: 0.1702 kWh, Discharge (bound/limit): -0.1615/0.1615, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.2064 kWh
# Net: 0.5393, Avl Energy: 0.3660 kWh, Discharge (bound/limit): -0.3473/0.3473, Charge (bound/limit): 0.4167/0.4167
# Discharging! -0.3473 kWh
# Net: -0.0283, Avl Energy: 0.0000 kWh, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Discharging! 0.0000 kWh
# Net: 0.2024, Avl Energy: 0.0000 kWh, Discharge (bound/limit): -0.0000/0.0000, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.0337 kWh
# Net: 0.7229, Avl Energy: 0.0319 kWh, Discharge (bound/limit): -0.0303/0.0303, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.1819 kWh
# Net: 0.0271, Avl Energy: 0.2045 kWh, Discharge (bound/limit): -0.1940/0.1940, Charge (bound/limit): 0.4167/0.4167
# Discharging! -0.0398 kWh
# Net: -0.3125, Avl Energy: 0.1626 kWh, Discharge (bound/limit): -0.1542/0.1542, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.0880 kWh
#
# Available Energy 0.5 kWh
# Max input: 0.4167 kWh
# Max output: 0.4167 kWh
#
# Net: -0.5257, Avl Energy: 0.5000 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.0042 kWh
# Net: 0.0867, Avl Energy: 0.5040 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.0800 kWh
# Net: 0.1562, Avl Energy: 0.5799 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Discharging! -0.0715 kWh
# Net: -0.1322, Avl Energy: 0.5044 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Discharging! -0.2399 kWh
# Net: -0.1664, Avl Energy: 0.2516 kWh, Discharge (bound/limit): -0.2387/0.2387, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.1519 kWh
# Net: -0.0466, Avl Energy: 0.3957 kWh, Discharge (bound/limit): -0.3754/0.3754, Charge (bound/limit): 0.4167/0.4167
# Discharging! -0.3274 kWh
# Net: 0.5801, Avl Energy: 0.0506 kWh, Discharge (bound/limit): -0.0480/0.0480, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.2712 kWh
# Net: -0.0044, Avl Energy: 0.3078 kWh, Discharge (bound/limit): -0.2920/0.2920, Charge (bound/limit): 0.4167/0.4167
# Discharging! -0.0415 kWh
# Net: -0.0154, Avl Energy: 0.2641 kWh, Discharge (bound/limit): -0.2506/0.2506, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.0325 kWh
# Net: 0.0794, Avl Energy: 0.2949 kWh, Discharge (bound/limit): -0.2798/0.2798, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.2689 kWh
#
# Available Energy 1 kWh
# Max input: 0.0000 kWh
# Max output: 0.4167 kWh
#
# Net: 0.2648, Avl Energy: 1.0000 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0000/0.0000
# Discharging! -0.2778 kWh
# Net: -0.0728, Avl Energy: 0.7072 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.3086/0.3086
# Charging! 0.2867 kWh
# Net: 0.2980, Avl Energy: 0.9791 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0220/0.0220
# Discharging! -0.0002 kWh
# Net: -0.7716, Avl Energy: 0.9790 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0222/0.0222
# Discharging! -0.3768 kWh
# Net: -0.1880, Avl Energy: 0.5818 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.3662 kWh
# Net: -0.2041, Avl Energy: 0.9292 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.0746/0.0746
# Discharging! -0.1239 kWh
# Net: -0.0233, Avl Energy: 0.7986 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.2123/0.2123
# Discharging! -0.1054 kWh
# Net: 0.1813, Avl Energy: 0.6875 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.3294/0.3294
# Discharging! -0.0776 kWh
# Net: 0.4316, Avl Energy: 0.6058 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4155/0.4155
# Discharging! -0.0636 kWh
# Net: 0.5631, Avl Energy: 0.5387 kWh, Discharge (bound/limit): -0.4167/0.4167, Charge (bound/limit): 0.4167/0.4167
# Charging! 0.0126 kWh
